# %%
import itertools
import sys
import math

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
from tqdm import trange

from bayes_module import Bayes_1d, Bayes_2d

# %% [markdown]
# 地震動の場合、解析解が複雑になってしまうので正弦波で解析を行う
#
# - 正弦波の場合の解析解を求めて、地震動とその変位のデータを作成する
# - 尤度関数は適当な正規分布を当てはめて、ベイズ推定をしてみる
# - 問題となるのは事前分布のkde（そもそも離散化したままで良い？サンプル数を増やす？）
# - 1つに定まらないので、確率的にどのセットが破損している確率が高いかが示せれば良い
# - その後の課題として同時に壊れやすいところを共分散をいじることで（指定するのは相関係数）表現する
# - ダンパを入れた時にどうなるのか
# - 3自由度にするとどうなるのか
# - 徐々に壊れていくものを検知できるか

# %% [markdown]
# # 1自由度バネマス系

# %%
# 微分方程式を離散化
delta = 1e-2
delta2 = delta**2
time_range = 10.0
steps = int(time_range/delta)
x = np.linspace(0.0, time_range, steps)
m = 1e5
k = 4e7
x_pre, x_cur = 0.0, 0.0
x_his = [x_cur]
# 一層目(地面)の加速度：地震の加速度*(-1)
amp = 1  # 振幅
ground_acc = amp * np.sin(np.pi*x)

for i in trange(steps):
    x_next = -x_cur/m*delta2*k + 2*x_cur - x_pre - ground_acc[i]*delta2
    x_his.append(x_next)
    x_pre, x_cur = x_cur, x_next
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 161294.57it/s]

# %%
# 理論解
w = np.sqrt(k/m)
theoretical_dis = +np.pi/(w*(w**2-np.pi**2))*np.sin(w*x) - 1/(w**2-np.pi**2)*np.sin(np.pi*x)

# %%
# RESPの計算結果
resp_dis = pd.read_csv('output_resp/single_Dis.csv')['N002:DIS:UX']

# %%
dis = pd.read_csv('output_resp/single_Dis.csv')['N002:DIS:UX']
acc = pd.read_csv('output_resp/single_ACC.csv')['N001:ACC:UX']

# %%
plt.figure(figsize=[13,8])
plt.plot(dis)

# %% [markdown]
# ### 比較

# %%
plt.figure(figsize=[10, 6])
plt.plot(x_his, label='numeric')
plt.plot(theoretical_dis, label='theory')
plt.plot(resp_dis, label='resp')
plt.xlabel('timestep')
plt.ylabel('displacement')
plt.legend()

# %% [markdown]
# 数値計算と理論解とRESP計算が一致することが確認できた

# %% [markdown]
# ## ベイズ推定 ~1自由度~

# %%
k_senarios_1d = [1e7, 2e7, 3e7, 4e7, 5e7, 6e7, 7e7]
# k_senarios_1d = [3e7, 3.5e7, 3.75e7, 4.1e7, 4.24e7, 4.5e7, 4.75e7]
acc_end = pd.read_csv('output_resp/single_ACC.csv')['N001:ACC:UX']

# %%
bayes_1d = Bayes_1d(k_senarios_1d, acc_end, resp_dis)

# %%
bayes_1d.infer()  # 逐次推定する
# Out:
# 1001it [00:01, 689.28it/s]

# %%
plt.figure(figsize=[13,8])
plt.plot(bayes_1d.dist_his)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbe28bd1690>,
#  <matplotlib.lines.Line2D at 0x7fbe28bd1910>,
#  <matplotlib.lines.Line2D at 0x7fbe28bd1ad0>,
#  <matplotlib.lines.Line2D at 0x7fbe28bd1c90>,
#  <matplotlib.lines.Line2D at 0x7fbe28bd1e50>,
#  <matplotlib.lines.Line2D at 0x7fbe28be2050>,
#  <matplotlib.lines.Line2D at 0x7fbe28be2290>]

# %%
plt.plot(bayes_1d.dist_his[:50])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbe288e32d0>,
#  <matplotlib.lines.Line2D at 0x7fbe288d9550>,
#  <matplotlib.lines.Line2D at 0x7fbe288d9750>,
#  <matplotlib.lines.Line2D at 0x7fbe288d9f90>,
#  <matplotlib.lines.Line2D at 0x7fbe288d9d90>,
#  <matplotlib.lines.Line2D at 0x7fbe288d9a10>,
#  <matplotlib.lines.Line2D at 0x7fbe288d9710>]

# %% [markdown]
# 位相ごとの収束回数を計測する

# %%
infer_counts_1d = bayes_1d.infer_counts(400, 3)
# Out:
# 14%|█▎        | 54/400 [00:52<05:33,  1.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-82b6a1d9c049> in <module>
# ----> 1 infer_counts_1d = bayes_1d.infer_counts(400, 3)
#
# ~/Desktop/卒業研究/research/bayes_module.py in infer_counts(self, phase_qty, true_index)
#     130
#     131                     for j, k_conditioned in enumerate(self.senarios):
# --> 132                         p_likelihood = self.likelihood(x_pre, x_cur, x_next, k_conditioned, f_cur)  # 尤度の計算
#     133                         p = p_likelihood * prior[j]  # 尤度と事前確率の積
#     134                         if math.isnan(p) or p < eps:
#
# ~/Desktop/卒業研究/research/bayes_module.py in likelihood(self, x_pre, x_cur, x_next, k_conditioned, f)
#     102         mu = -x_cur/self.m*self.delta2*k_conditioned + 2*x_cur - x_pre - f*self.delta2  # 平均
#     103         std = np.abs(self.delta2/self.m*x_cur*k_std) # 標準偏差
# --> 104         p = st.norm.pdf(x_next, loc=mu, scale=std)
#     105         return p
#     106
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1745         putmask(output, (1-cond0)+np.isnan(x), self.badvalue)
#    1746         if np.any(cond):
# -> 1747             goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#    1748             scale, goodargs = goodargs[-1], goodargs[:-1]
#    1749             place(output, cond, self._pdf(*goodargs) / scale)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in argsreduce(cond, *args)
#     543         newargs = [newargs, ]
#     544     expand_arr = (cond == cond)
# --> 545     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#     546
#     547
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in <listcomp>(.0)
#     543         newargs = [newargs, ]
#     544     expand_arr = (cond == cond)
# --> 545     return [np.extract(cond, arr1 * expand_arr) for arr1 in newargs]
#     546
#     547
#
# <__array_function__ internals> in extract(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in extract(condition, arr)
#    1643
#    1644
# -> 1645 @array_function_dispatch(_extract_dispatcher)
#    1646 def extract(condition, arr):
#    1647     """
#
# KeyboardInterrupt:

# %%
plt.plot(infer_counts_1d)

# %% [markdown]
# 1自由度において上手く推定できることが確認できた
#
# 変位が0に近いときは分散も0に近くなるので推定結果がほとんど変化しないことは面白い

# %% [markdown]
# # ２自由度バネマス系

# %%
# respの解析結果を読み込む
dis_down = pd.read_csv('output_resp/double_downDis.csv')['N002:DIS:UX']
dis_up = pd.read_csv('output_resp/double_upDis.csv')['N003:DIS:UX']
acc_end = pd.read_csv('output_resp/double_endAcc.csv')['N001:ACC:UX']

# %%
# 微分方程式を離散化
delta = 1e-2
delta2 = delta**2
time_range = 10.0
steps = int(time_range/delta)
x = np.linspace(0.0, time_range, steps)
m1 = 1e5
m2 = 8e4
k1 = 4e7
k2 = 3e7
x1_cur, x2_cur, x1_pre, x2_pre = 0.0, 0.0, 0.0, 0.0
x1_his = [x1_cur]
x2_his = [x2_cur]
# 一層目(地面)の加速度：地震の加速度*(-1)
acc_numerical_simulate = np.sin(np.pi*x)

for i in trange(steps):
    x1_next = -delta2/m1*x1_cur*k1 - delta2/m1*(x1_cur-x2_cur)*k2 + 2*x1_cur - x1_pre - acc_numerical_simulate[i]*delta2
    x2_next = delta2/m2*(x1_cur-x2_cur)*k2 + 2*x2_cur - x2_pre- acc_numerical_simulate[i]*delta2
    x1_his.append(x1_next)
    x2_his.append(x2_next)
    x1_pre, x2_pre, x1_cur, x2_cur = x1_cur, x2_cur, x1_next, x2_next
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 103135.24it/s]

# %%
plt.plot(dis_down)
plt.plot(dis_up)

# %%
plt.figure(figsize=[13,8])
plt.plot(x1_his, label='numerical')
plt.plot(dis_down, label='resp')
plt.title('dis down')
plt.legend()

# %%
plt.figure(figsize=[13,8])
plt.plot(x2_his, label='numerical')
plt.plot(dis_up, label='resp')
plt.title('dis up')
plt.legend()

# %%
k1_list = [1e7, 2e7, 3e7, 4e7, 5e7, 6e7, 7e7]
k2_list = [1e7, 2e7, 3e7, 4e7, 5e7, 6e7, 7e7]
k_senarios_2d = list(itertools.product(k1_list, k2_list))  # パラメータkの組み合わせ

# %%
bayes_2d = Bayes_2d(k_senarios_2d, acc_end, dis_down, dis_up)

# %%
bayes_2d.infer()
# Out:
# 1001it [00:11, 89.04it/s]

# %%
plt.figure(figsize=[13,8])
plt.plot(bayes_2d.dist_his)
# Out:
# [<matplotlib.lines.Line2D at 0x7ff1c66f9750>,
#  <matplotlib.lines.Line2D at 0x7ff1c66f9990>,
#  <matplotlib.lines.Line2D at 0x7ff1c66f9b50>,
#  <matplotlib.lines.Line2D at 0x7ff1c66f9d10>,
#  <matplotlib.lines.Line2D at 0x7ff1c66f9ed0>,
#  <matplotlib.lines.Line2D at 0x7ff1c67010d0>,
#  <matplotlib.lines.Line2D at 0x7ff1c6701310>,
#  <matplotlib.lines.Line2D at 0x7ff1c67014d0>,
#  <matplotlib.lines.Line2D at 0x7ff1c66f9e90>,
#  <matplotlib.lines.Line2D at 0x7ff1c6701110>,
#  <matplotlib.lines.Line2D at 0x7ff1c6501550>,
#  <matplotlib.lines.Line2D at 0x7ff1c6701b10>,
#  <matplotlib.lines.Line2D at 0x7ff1c6701cd0>,
#  <matplotlib.lines.Line2D at 0x7ff1c6701e90>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705090>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705250>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705410>,
#  <matplotlib.lines.Line2D at 0x7ff1c67055d0>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705790>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705950>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705b10>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705cd0>,
#  <matplotlib.lines.Line2D at 0x7ff1c6705e90>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709090>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709250>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709410>,
#  <matplotlib.lines.Line2D at 0x7ff1c67095d0>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709790>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709950>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709b10>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709cd0>,
#  <matplotlib.lines.Line2D at 0x7ff1c6709e90>,
#  <matplotlib.lines.Line2D at 0x7ff1c670c090>,
#  <matplotlib.lines.Line2D at 0x7ff1c670c250>,
#  <matplotlib.lines.Line2D at 0x7ff1c670c410>,
#  <matplotlib.lines.Line2D at 0x7ff1c670c5d0>,
#  <matplotlib.lines.Line2D at 0x7ff1c670c790>,
#  <matplotlib.lines.Line2D at 0x7ff1c670c950>,
#  <matplotlib.lines.Line2D at 0x7ff1c670cb10>,
#  <matplotlib.lines.Line2D at 0x7ff1c670ccd0>,
#  <matplotlib.lines.Line2D at 0x7ff1c670ce90>,
#  <matplotlib.lines.Line2D at 0x7ff1c6710090>,
#  <matplotlib.lines.Line2D at 0x7ff1c6710250>,
#  <matplotlib.lines.Line2D at 0x7ff1c6710410>,
#  <matplotlib.lines.Line2D at 0x7ff1c67105d0>,
#  <matplotlib.lines.Line2D at 0x7ff1c6710790>,
#  <matplotlib.lines.Line2D at 0x7ff1c6710950>,
#  <matplotlib.lines.Line2D at 0x7ff1c6710b10>,
#  <matplotlib.lines.Line2D at 0x7ff1c6710cd0>]

# %%
plt.figure(figsize=[13,8])
plt.plot(bayes_2d.dist_his)
plt.xlim([0, 50])
# Out:
# (0, 50)

# %%
infer_counts_2d = bayes_2d.infer_counts(400, 23)

# %%
plt.plot(infer_counts_2d)
